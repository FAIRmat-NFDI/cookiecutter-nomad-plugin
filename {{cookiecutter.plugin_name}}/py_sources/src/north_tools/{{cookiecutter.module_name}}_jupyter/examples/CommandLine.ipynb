# %% [markdown]
# # Jupyter Notebook as a Placeholder for NOMAD north tool hub
#
# This Notebook mainly runs a few commands for testing purpose. As plugin developer you remove the entire content of the file or rename the file or delete file and create new one according to your requirements.
# If you rename or relocate the file, please update the corresponding file path in the north publish CI/CD workflow (or search the project directory for this notebook name).

# %% [markdown]
# ## Prints the available python library in this environment using uv

# %%
# !uv pip list

# %% [markdown]
# ## Prints the available python library in this environment using pip, it gives the same result as the previou command.

# %%
# !pip list
